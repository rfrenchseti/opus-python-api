# %%
from opusapi import *

# %%
O=OPUSAPI()

# %%
O
# Out:
# OPUSAPI for server https://opus.pds-rings.seti.org

# %%
print(O)
# Out:
# https://opus.pds-rings.seti.org

# %% [markdown]
# # RAW FIELDS are exactly as they are returned from the OPUS server, with no post-processing done.

# %%
rf=O.raw_fields

# %%
len(rf)
# Out:
# 3324

# %%
list(rf.keys())[:20]
# Out:
# ['planet',
#  'target',
#  'targetclass',
#  'mission',
#  'insthost',
#  'instrument',
#  'observationtype',
#  'time1',
#  'time2',
#  'observationduration',
#  'quantity',
#  'rightasc1',
#  'rightasc2',
#  'declination1',
#  'declination2',
#  'ringobsid',
#  'volumeid',
#  'datasetid',
#  'productid',
#  'productcreationtime']

# %%
rf['rightasc1']
# Out:
# {'available_units': ['degrees', 'hourangle', 'radians'],
#  'category': 'General Constraints',
#  'default_units': 'degrees',
#  'field_id': 'rightasc1',
#  'full_label': 'Right Ascension (Min)',
#  'full_search_label': 'Right Ascension [General]',
#  'label': 'Right Ascension (Min)',
#  'search_label': 'Right Ascension',
#  'type': 'range_longitude'}

# %%
rfdf=O.raw_fields_as_df

# %%
rfdf
# Out:
#                                                                 available_units  \
# planet                                                                     None
# target                                                                     None
# targetclass                                                                None
# mission                                                                    None
# insthost                                                                   None
# instrument                                                                 None
# observationtype                                                            None
# time1                                                                      None
# time2                                                                      None
# observationduration               [seconds, milliseconds, minutes, hours, days]
# quantity                                                                   None
# rightasc1                                         [degrees, hourangle, radians]
# rightasc2                                         [degrees, hourangle, radians]
# declination1                                      [degrees, hourangle, radians]
# declination2                                      [degrees, hourangle, radians]
# ringobsid                                                                  None
# volumeid                                                                   None
# datasetid                                                                  None
# productid                                                                  None
# productcreationtime                                                        None
# primaryfilespec                                                            None
# opusid                                                                     None
# note                                                                       None
# duration                          [seconds, milliseconds, minutes, hours, days]
# greaterpixelsize                                                           None
# lesserpixelsize                                                            None
# levels                                                                     None
# imagetype                                                                  None
# wavelength1                                        [microns, angstroms, nm, cm]
# wavelength2                                        [microns, angstroms, nm, cm]
# ...                                                                         ...
# COVIMSvisexposure                 [seconds, milliseconds, minutes, hours, days]
# COVIMSirsamplingmode                                                       None
# COVIMSirexposure                  [seconds, milliseconds, minutes, hours, days]
# COVIMSswathwidth                                                           None
# COVIMSswathlength                                                          None
# COVIMSspectralsumming                                                      None
# COVIMSspectralediting                                                      None
# COVIMSinstrumentmode                                                       None
# COVIMSstartracking                                                         None
# GOSSIfilter                                                                None
# GOSSIfilternumber                                                          None
# GOSSIcompressiontype                                                       None
# GOSSIgainmode                                                              None
# GOSSIobstruction                                                           None
# GOSSIframeduration                                                         None
# GOSSIimageid                                                               None
# GOSSIobservationid                                                         None
# NHLORRIbinningmode                                                         None
# NHLORRIinstrumentcompressiontype                                           None
# NHMVICinstrumentcompressiontype                                            None
# VGISScamera                                                                None
# VGISSfilter                                                                None
# VGISSfilternumber                                                          None
# VGISSshuttermode                                                           None
# VGISSeditmode                                                              None
# VGISSgainmode                                                              None
# VGISSscanmode                                                              None
# VGISSimageid                                                               None
# VGISSusablelines                                                           None
# VGISSusablesamples                                                         None
#
#                                                         category  \
# planet                                       General Constraints
# target                                       General Constraints
# targetclass                                  General Constraints
# mission                                      General Constraints
# insthost                                     General Constraints
# instrument                                   General Constraints
# observationtype                              General Constraints
# time1                                        General Constraints
# time2                                        General Constraints
# observationduration                          General Constraints
# quantity                                     General Constraints
# rightasc1                                    General Constraints
# rightasc2                                    General Constraints
# declination1                                 General Constraints
# declination2                                 General Constraints
# ringobsid                                    General Constraints
# volumeid                                         PDS Constraints
# datasetid                                        PDS Constraints
# productid                                        PDS Constraints
# productcreationtime                              PDS Constraints
# primaryfilespec                                  PDS Constraints
# opusid                                           PDS Constraints
# note                                             PDS Constraints
# duration                                       Image Constraints
# greaterpixelsize                               Image Constraints
# lesserpixelsize                                Image Constraints
# levels                                         Image Constraints
# imagetype                                      Image Constraints
# wavelength1                               Wavelength Constraints
# wavelength2                               Wavelength Constraints
# ...                                                          ...
# COVIMSvisexposure                       Cassini VIMS Constraints
# COVIMSirsamplingmode                    Cassini VIMS Constraints
# COVIMSirexposure                        Cassini VIMS Constraints
# COVIMSswathwidth                        Cassini VIMS Constraints
# COVIMSswathlength                       Cassini VIMS Constraints
# COVIMSspectralsumming                   Cassini VIMS Constraints
# COVIMSspectralediting                   Cassini VIMS Constraints
# COVIMSinstrumentmode                    Cassini VIMS Constraints
# COVIMSstartracking                      Cassini VIMS Constraints
# GOSSIfilter                              Galileo SSI Constraints
# GOSSIfilternumber                        Galileo SSI Constraints
# GOSSIcompressiontype                     Galileo SSI Constraints
# GOSSIgainmode                            Galileo SSI Constraints
# GOSSIobstruction                         Galileo SSI Constraints
# GOSSIframeduration                       Galileo SSI Constraints
# GOSSIimageid                             Galileo SSI Constraints
# GOSSIobservationid                       Galileo SSI Constraints
# NHLORRIbinningmode                New Horizons LORRI Constraints
# NHLORRIinstrumentcompressiontype  New Horizons LORRI Constraints
# NHMVICinstrumentcompressiontype    New Horizons MVIC Constraints
# VGISScamera                              Voyager ISS Constraints
# VGISSfilter                              Voyager ISS Constraints
# VGISSfilternumber                        Voyager ISS Constraints
# VGISSshuttermode                         Voyager ISS Constraints
# VGISSeditmode                            Voyager ISS Constraints
# VGISSgainmode                            Voyager ISS Constraints
# VGISSscanmode                            Voyager ISS Constraints
# VGISSimageid                             Voyager ISS Constraints
# VGISSusablelines                         Voyager ISS Constraints
# VGISSusablesamples                       Voyager ISS Constraints
#
#                                  default_units  \
# planet                                    None
# target                                    None
# targetclass                               None
# mission                                   None
# insthost                                  None
# instrument                                None
# observationtype                           None
# time1                                     None
# time2                                     None
# observationduration                    seconds
# quantity                                  None
# rightasc1                              degrees
# rightasc2                              degrees
# declination1                           degrees
# declination2                           degrees
# ringobsid                                 None
# volumeid                                  None
# datasetid                                 None
# productid                                 None
# productcreationtime                       None
# primaryfilespec                           None
# opusid                                    None
# note                                      None
# duration                               seconds
# greaterpixelsize                          None
# lesserpixelsize                           None
# levels                                    None
# imagetype                                 None
# wavelength1                            microns
# wavelength2                            microns
# ...                                        ...
# COVIMSvisexposure                      seconds
# COVIMSirsamplingmode                      None
# COVIMSirexposure                       seconds
# COVIMSswathwidth                          None
# COVIMSswathlength                         None
# COVIMSspectralsumming                     None
# COVIMSspectralediting                     None
# COVIMSinstrumentmode                      None
# COVIMSstartracking                        None
# GOSSIfilter                               None
# GOSSIfilternumber                         None
# GOSSIcompressiontype                      None
# GOSSIgainmode                             None
# GOSSIobstruction                          None
# GOSSIframeduration                        None
# GOSSIimageid                              None
# GOSSIobservationid                        None
# NHLORRIbinningmode                        None
# NHLORRIinstrumentcompressiontype          None
# NHMVICinstrumentcompressiontype           None
# VGISScamera                               None
# VGISSfilter                               None
# VGISSfilternumber                         None
# VGISSshuttermode                          None
# VGISSeditmode                             None
# VGISSgainmode                             None
# VGISSscanmode                             None
# VGISSimageid                              None
# VGISSusablelines                          None
# VGISSusablesamples                        None
#
#                                                                         full_label  \
# planet                                                                      Planet
# target                                                        Intended Target Name
# targetclass                                                   Nominal Target Class
# mission                                                                    Mission
# insthost                                                      Instrument Host Name
# instrument                                                         Instrument Name
# observationtype                                                   Observation Type
# time1                                                       Observation Start Time
# time2                                                        Observation Stop Time
# observationduration                                           Observation Duration
# quantity                                                      Measurement Quantity
# rightasc1                                                    Right Ascension (Min)
# rightasc2                                                    Right Ascension (Max)
# declination1                                                     Declination (Min)
# declination2                                                     Declination (Max)
# ringobsid                                                              RING OBS ID
# volumeid                                                                 Volume ID
# datasetid                                                              Data Set ID
# productid                                                               Product ID
# productcreationtime                                          Product Creation Time
# primaryfilespec                                                  Primary File Spec
# opusid                                                                     OPUS ID
# note                                                                          Note
# duration                                                         Exposure Duration
# greaterpixelsize                                            Greater Size in Pixels
# lesserpixelsize                                              Lesser Size in Pixels
# levels                                                            Intensity Levels
# imagetype                                                               Image Type
# wavelength1                                                       Wavelength (Min)
# wavelength2                                                       Wavelength (Max)
# ...                                                                            ...
# COVIMSvisexposure                                      VIS Exposure [Cassini VIMS]
# COVIMSirsamplingmode                               IR Sampling Mode [Cassini VIMS]
# COVIMSirexposure                                        IR Exposure [Cassini VIMS]
# COVIMSswathwidth                                        Swath Width [Cassini VIMS]
# COVIMSswathlength                                      Swath Length [Cassini VIMS]
# COVIMSspectralsumming                              Spectral Summing [Cassini VIMS]
# COVIMSspectralediting                              Spectral Editing [Cassini VIMS]
# COVIMSinstrumentmode                                Instrument Mode [Cassini VIMS]
# COVIMSstartracking                                    Star Tracking [Cassini VIMS]
# GOSSIfilter                                              Filter Name [Galileo SSI]
# GOSSIfilternumber                                      Filter Number [Galileo SSI]
# GOSSIcompressiontype                                Compression Type [Galileo SSI]
# GOSSIgainmode                                              Gain Mode [Galileo SSI]
# GOSSIobstruction                                         Obstruction [Galileo SSI]
# GOSSIframeduration                                    Frame Duration [Galileo SSI]
# GOSSIimageid                                                Image ID [Galileo SSI]
# GOSSIobservationid                                    Observation ID [Galileo SSI]
# NHLORRIbinningmode                               Binning Mode [New Horizons LORRI]
# NHLORRIinstrumentcompressiontype  Instrument Compression Type [New Horizons LORRI]
# NHMVICinstrumentcompressiontype    Instrument Compression Type [New Horizons MVIC]
# VGISScamera                                                   Camera [Voyager ISS]
# VGISSfilter                                              Filter Name [Voyager ISS]
# VGISSfilternumber                                      Filter Number [Voyager ISS]
# VGISSshuttermode                                        Shutter Mode [Voyager ISS]
# VGISSeditmode                                              Edit Mode [Voyager ISS]
# VGISSgainmode                                              Gain Mode [Voyager ISS]
# VGISSscanmode                                              Scan Mode [Voyager ISS]
# VGISSimageid                                                Image ID [Voyager ISS]
# VGISSusablelines                                        Usable Lines [Voyager ISS]
# VGISSusablesamples                                    Usable Samples [Voyager ISS]
#
#                                                                  full_search_label  \
# planet                                                            Planet [General]
# target                                              Intended Target Name [General]
# targetclass                                         Nominal Target Class [General]
# mission                                                          Mission [General]
# insthost                                            Instrument Host Name [General]
# instrument                                               Instrument Name [General]
# observationtype                                         Observation Type [General]
# time1                                                   Observation Time [General]
# time2                                                   Observation Time [General]
# observationduration                                 Observation Duration [General]
# quantity                                            Measurement Quantity [General]
# rightasc1                                                Right Ascension [General]
# rightasc2                                                Right Ascension [General]
# declination1                                                 Declination [General]
# declination2                                                 Declination [General]
# ringobsid                                                    RING OBS ID [General]
# volumeid                                                           Volume ID [PDS]
# datasetid                                                        Data Set ID [PDS]
# productid                                                         Product ID [PDS]
# productcreationtime                                    Product Creation Time [PDS]
# primaryfilespec                                            Primary File Spec [PDS]
# opusid                                                               OPUS ID [PDS]
# note                                                                    Note [PDS]
# duration                                                 Exposure Duration [Image]
# greaterpixelsize                                    Greater Size in Pixels [Image]
# lesserpixelsize                                      Lesser Size in Pixels [Image]
# levels                                                    Intensity Levels [Image]
# imagetype                                                       Image Type [Image]
# wavelength1                                                Wavelength [Wavelength]
# wavelength2                                                Wavelength [Wavelength]
# ...                                                                            ...
# COVIMSvisexposure                                      VIS Exposure [Cassini VIMS]
# COVIMSirsamplingmode                               IR Sampling Mode [Cassini VIMS]
# COVIMSirexposure                                        IR Exposure [Cassini VIMS]
# COVIMSswathwidth                                        Swath Width [Cassini VIMS]
# COVIMSswathlength                                      Swath Length [Cassini VIMS]
# COVIMSspectralsumming                              Spectral Summing [Cassini VIMS]
# COVIMSspectralediting                              Spectral Editing [Cassini VIMS]
# COVIMSinstrumentmode                                Instrument Mode [Cassini VIMS]
# COVIMSstartracking                                    Star Tracking [Cassini VIMS]
# GOSSIfilter                                              Filter Name [Galileo SSI]
# GOSSIfilternumber                                      Filter Number [Galileo SSI]
# GOSSIcompressiontype                                Compression Type [Galileo SSI]
# GOSSIgainmode                                              Gain Mode [Galileo SSI]
# GOSSIobstruction                                         Obstruction [Galileo SSI]
# GOSSIframeduration                                    Frame Duration [Galileo SSI]
# GOSSIimageid                                                Image ID [Galileo SSI]
# GOSSIobservationid                                    Observation ID [Galileo SSI]
# NHLORRIbinningmode                               Binning Mode [New Horizons LORRI]
# NHLORRIinstrumentcompressiontype  Instrument Compression Type [New Horizons LORRI]
# NHMVICinstrumentcompressiontype    Instrument Compression Type [New Horizons MVIC]
# VGISScamera                                                   Camera [Voyager ISS]
# VGISSfilter                                              Filter Name [Voyager ISS]
# VGISSfilternumber                                      Filter Number [Voyager ISS]
# VGISSshuttermode                                        Shutter Mode [Voyager ISS]
# VGISSeditmode                                              Edit Mode [Voyager ISS]
# VGISSgainmode                                              Gain Mode [Voyager ISS]
# VGISSscanmode                                              Scan Mode [Voyager ISS]
# VGISSimageid                                                Image ID [Voyager ISS]
# VGISSusablelines                                        Usable Lines [Voyager ISS]
# VGISSusablesamples                                    Usable Samples [Voyager ISS]
#
#                                                         label  \
# planet                                                 Planet
# target                                   Intended Target Name
# targetclass                              Nominal Target Class
# mission                                               Mission
# insthost                                 Instrument Host Name
# instrument                                    Instrument Name
# observationtype                              Observation Type
# time1                                  Observation Start Time
# time2                                   Observation Stop Time
# observationduration                      Observation Duration
# quantity                                 Measurement Quantity
# rightasc1                               Right Ascension (Min)
# rightasc2                               Right Ascension (Max)
# declination1                                Declination (Min)
# declination2                                Declination (Max)
# ringobsid                                         RING OBS ID
# volumeid                                            Volume ID
# datasetid                                         Data Set ID
# productid                                          Product ID
# productcreationtime                     Product Creation Time
# primaryfilespec                             Primary File Spec
# opusid                                                OPUS ID
# note                                                     Note
# duration                                    Exposure Duration
# greaterpixelsize                       Greater Size in Pixels
# lesserpixelsize                         Lesser Size in Pixels
# levels                                       Intensity Levels
# imagetype                                          Image Type
# wavelength1                                  Wavelength (Min)
# wavelength2                                  Wavelength (Max)
# ...                                                       ...
# COVIMSvisexposure                                VIS Exposure
# COVIMSirsamplingmode                         IR Sampling Mode
# COVIMSirexposure                                  IR Exposure
# COVIMSswathwidth                                  Swath Width
# COVIMSswathlength                                Swath Length
# COVIMSspectralsumming                        Spectral Summing
# COVIMSspectralediting                        Spectral Editing
# COVIMSinstrumentmode                          Instrument Mode
# COVIMSstartracking                              Star Tracking
# GOSSIfilter                                       Filter Name
# GOSSIfilternumber                               Filter Number
# GOSSIcompressiontype                         Compression Type
# GOSSIgainmode                                       Gain Mode
# GOSSIobstruction                                  Obstruction
# GOSSIframeduration                             Frame Duration
# GOSSIimageid                                         Image ID
# GOSSIobservationid                             Observation ID
# NHLORRIbinningmode                               Binning Mode
# NHLORRIinstrumentcompressiontype  Instrument Compression Type
# NHMVICinstrumentcompressiontype   Instrument Compression Type
# VGISScamera                                            Camera
# VGISSfilter                                       Filter Name
# VGISSfilternumber                               Filter Number
# VGISSshuttermode                                 Shutter Mode
# VGISSeditmode                                       Edit Mode
# VGISSgainmode                                       Gain Mode
# VGISSscanmode                                       Scan Mode
# VGISSimageid                                         Image ID
# VGISSusablelines                                 Usable Lines
# VGISSusablesamples                             Usable Samples
#
#                                                  search_label             type
# planet                                                 Planet         multiple
# target                                   Intended Target Name         multiple
# targetclass                              Nominal Target Class         multiple
# mission                                               Mission         multiple
# insthost                                 Instrument Host Name         multiple
# instrument                                    Instrument Name         multiple
# observationtype                              Observation Type         multiple
# time1                                        Observation Time       range_time
# time2                                        Observation Time       range_time
# observationduration                      Observation Duration      range_float
# quantity                                 Measurement Quantity         multiple
# rightasc1                                     Right Ascension  range_longitude
# rightasc2                                     Right Ascension  range_longitude
# declination1                                      Declination      range_float
# declination2                                      Declination      range_float
# ringobsid                                         RING OBS ID           string
# volumeid                                            Volume ID           string
# datasetid                                         Data Set ID           string
# productid                                          Product ID           string
# productcreationtime                     Product Creation Time       range_time
# primaryfilespec                             Primary File Spec           string
# opusid                                                OPUS ID           string
# note                                                     Note           string
# duration                                    Exposure Duration      range_float
# greaterpixelsize                       Greater Size in Pixels    range_integer
# lesserpixelsize                         Lesser Size in Pixels    range_integer
# levels                                       Intensity Levels    range_integer
# imagetype                                          Image Type         multiple
# wavelength1                                        Wavelength      range_float
# wavelength2                                        Wavelength      range_float
# ...                                                       ...              ...
# COVIMSvisexposure                                VIS Exposure      range_float
# COVIMSirsamplingmode                         IR Sampling Mode         multiple
# COVIMSirexposure                                  IR Exposure      range_float
# COVIMSswathwidth                                  Swath Width    range_integer
# COVIMSswathlength                                Swath Length    range_integer
# COVIMSspectralsumming                        Spectral Summing         multiple
# COVIMSspectralediting                        Spectral Editing         multiple
# COVIMSinstrumentmode                          Instrument Mode         multiple
# COVIMSstartracking                              Star Tracking         multiple
# GOSSIfilter                                       Filter Name         multiple
# GOSSIfilternumber                               Filter Number         multiple
# GOSSIcompressiontype                         Compression Type         multiple
# GOSSIgainmode                                       Gain Mode         multiple
# GOSSIobstruction                                  Obstruction         multiple
# GOSSIframeduration                             Frame Duration         multiple
# GOSSIimageid                                         Image ID           string
# GOSSIobservationid                             Observation ID           string
# NHLORRIbinningmode                               Binning Mode         multiple
# NHLORRIinstrumentcompressiontype  Instrument Compression Type         multiple
# NHMVICinstrumentcompressiontype   Instrument Compression Type         multiple
# VGISScamera                                            Camera         multiple
# VGISSfilter                                       Filter Name         multiple
# VGISSfilternumber                               Filter Number         multiple
# VGISSshuttermode                                 Shutter Mode         multiple
# VGISSeditmode                                       Edit Mode         multiple
# VGISSgainmode                                       Gain Mode         multiple
# VGISSscanmode                                       Scan Mode         multiple
# VGISSimageid                                         Image ID           string
# VGISSusablelines                                 Usable Lines    range_integer
# VGISSusablesamples                             Usable Samples    range_integer
#
# [3324 rows x 8 columns]

# %% [markdown]
# # NON-RAW FIELDS have been processed. Two-value fields (e.g. rightasc1 and rightasc2) have been combined into one.

# %%
f=O.fields

# %%
len(f)
# Out:
# 2177

# %%
list(f.keys())[:20]
# Out:
# ['planet',
#  'target',
#  'targetclass',
#  'mission',
#  'insthost',
#  'instrument',
#  'observationtype',
#  'time',
#  'observationduration',
#  'quantity',
#  'rightasc',
#  'declination',
#  'ringobsid',
#  'volumeid',
#  'datasetid',
#  'productid',
#  'productcreationtime',
#  'primaryfilespec',
#  'opusid',
#  'note']

# %%
f['rightasc']
# Out:
# {'available_units': ['degrees', 'hourangle', 'radians'],
#  'category': 'General Constraints',
#  'default_units': 'degrees',
#  'fieldid1': 'rightasc1',
#  'fieldid2': 'rightasc2',
#  'full_label1': 'Right Ascension (Min)',
#  'full_label2': 'Right Ascension (Max)',
#  'full_search_label': 'Right Ascension [General]',
#  'label1': 'Right Ascension (Min)',
#  'label2': 'Right Ascension (Max)',
#  'search_fieldid1': 'rightasc1',
#  'search_fieldid2': 'rightasc2',
#  'search_label': 'Right Ascension',
#  'single_value': False,
#  'type': 'range_longitude'}

# %%
fdf=O.fields_as_df

# %%
fdf
# Out:
#                                                                     available_units  \
# planet                                                                         None
# target                                                                         None
# targetclass                                                                    None
# mission                                                                        None
# insthost                                                                       None
# instrument                                                                     None
# observationtype                                                                None
# time                                                                           None
# observationduration                   [seconds, milliseconds, minutes, hours, days]
# quantity                                                                       None
# rightasc                                              [degrees, hourangle, radians]
# declination                                           [degrees, hourangle, radians]
# ringobsid                                                                      None
# volumeid                                                                       None
# datasetid                                                                      None
# productid                                                                      None
# productcreationtime                                                            None
# primaryfilespec                                                                None
# opusid                                                                         None
# note                                                                           None
# duration                              [seconds, milliseconds, minutes, hours, days]
# greaterpixelsize                                                               None
# lesserpixelsize                                                                None
# levels                                                                         None
# imagetype                                                                      None
# wavelength                                             [microns, angstroms, nm, cm]
# waveres                           [microns/pixel, angstroms/pixel, nm/pixel, cm/...
# waveno                                                                  [1/cm, 1/m]
# wavenores                                                   [1/cm/pixel, 1/m/pixel]
# specflag                                                                       None
# ...                                                                             ...
# COVIMSvisexposure                     [seconds, milliseconds, minutes, hours, days]
# COVIMSirsamplingmode                                                           None
# COVIMSirexposure                      [seconds, milliseconds, minutes, hours, days]
# COVIMSswathwidth                                                               None
# COVIMSswathlength                                                              None
# COVIMSspectralsumming                                                          None
# COVIMSspectralediting                                                          None
# COVIMSinstrumentmode                                                           None
# COVIMSstartracking                                                             None
# GOSSIfilter                                                                    None
# GOSSIfilternumber                                                              None
# GOSSIcompressiontype                                                           None
# GOSSIgainmode                                                                  None
# GOSSIobstruction                                                               None
# GOSSIframeduration                                                             None
# GOSSIimageid                                                                   None
# GOSSIobservationid                                                             None
# NHLORRIbinningmode                                                             None
# NHLORRIinstrumentcompressiontype                                               None
# NHMVICinstrumentcompressiontype                                                None
# VGISScamera                                                                    None
# VGISSfilter                                                                    None
# VGISSfilternumber                                                              None
# VGISSshuttermode                                                               None
# VGISSeditmode                                                                  None
# VGISSgainmode                                                                  None
# VGISSscanmode                                                                  None
# VGISSimageid                                                                   None
# VGISSusablelines                                                               None
# VGISSusablesamples                                                             None
#
#                                                         category  \
# planet                                       General Constraints
# target                                       General Constraints
# targetclass                                  General Constraints
# mission                                      General Constraints
# insthost                                     General Constraints
# instrument                                   General Constraints
# observationtype                              General Constraints
# time                                         General Constraints
# observationduration                          General Constraints
# quantity                                     General Constraints
# rightasc                                     General Constraints
# declination                                  General Constraints
# ringobsid                                    General Constraints
# volumeid                                         PDS Constraints
# datasetid                                        PDS Constraints
# productid                                        PDS Constraints
# productcreationtime                              PDS Constraints
# primaryfilespec                                  PDS Constraints
# opusid                                           PDS Constraints
# note                                             PDS Constraints
# duration                                       Image Constraints
# greaterpixelsize                               Image Constraints
# lesserpixelsize                                Image Constraints
# levels                                         Image Constraints
# imagetype                                      Image Constraints
# wavelength                                Wavelength Constraints
# waveres                                   Wavelength Constraints
# waveno                                    Wavelength Constraints
# wavenores                                 Wavelength Constraints
# specflag                                  Wavelength Constraints
# ...                                                          ...
# COVIMSvisexposure                       Cassini VIMS Constraints
# COVIMSirsamplingmode                    Cassini VIMS Constraints
# COVIMSirexposure                        Cassini VIMS Constraints
# COVIMSswathwidth                        Cassini VIMS Constraints
# COVIMSswathlength                       Cassini VIMS Constraints
# COVIMSspectralsumming                   Cassini VIMS Constraints
# COVIMSspectralediting                   Cassini VIMS Constraints
# COVIMSinstrumentmode                    Cassini VIMS Constraints
# COVIMSstartracking                      Cassini VIMS Constraints
# GOSSIfilter                              Galileo SSI Constraints
# GOSSIfilternumber                        Galileo SSI Constraints
# GOSSIcompressiontype                     Galileo SSI Constraints
# GOSSIgainmode                            Galileo SSI Constraints
# GOSSIobstruction                         Galileo SSI Constraints
# GOSSIframeduration                       Galileo SSI Constraints
# GOSSIimageid                             Galileo SSI Constraints
# GOSSIobservationid                       Galileo SSI Constraints
# NHLORRIbinningmode                New Horizons LORRI Constraints
# NHLORRIinstrumentcompressiontype  New Horizons LORRI Constraints
# NHMVICinstrumentcompressiontype    New Horizons MVIC Constraints
# VGISScamera                              Voyager ISS Constraints
# VGISSfilter                              Voyager ISS Constraints
# VGISSfilternumber                        Voyager ISS Constraints
# VGISSshuttermode                         Voyager ISS Constraints
# VGISSeditmode                            Voyager ISS Constraints
# VGISSgainmode                            Voyager ISS Constraints
# VGISSscanmode                            Voyager ISS Constraints
# VGISSimageid                             Voyager ISS Constraints
# VGISSusablelines                         Voyager ISS Constraints
# VGISSusablesamples                       Voyager ISS Constraints
#
#                                   default_units  \
# planet                                     None
# target                                     None
# targetclass                                None
# mission                                    None
# insthost                                   None
# instrument                                 None
# observationtype                            None
# time                                       None
# observationduration                     seconds
# quantity                                   None
# rightasc                                degrees
# declination                             degrees
# ringobsid                                  None
# volumeid                                   None
# datasetid                                  None
# productid                                  None
# productcreationtime                        None
# primaryfilespec                            None
# opusid                                     None
# note                                       None
# duration                                seconds
# greaterpixelsize                           None
# lesserpixelsize                            None
# levels                                     None
# imagetype                                  None
# wavelength                              microns
# waveres                           microns/pixel
# waveno                                     1/cm
# wavenores                            1/cm/pixel
# specflag                                   None
# ...                                         ...
# COVIMSvisexposure                       seconds
# COVIMSirsamplingmode                       None
# COVIMSirexposure                        seconds
# COVIMSswathwidth                           None
# COVIMSswathlength                          None
# COVIMSspectralsumming                      None
# COVIMSspectralediting                      None
# COVIMSinstrumentmode                       None
# COVIMSstartracking                         None
# GOSSIfilter                                None
# GOSSIfilternumber                          None
# GOSSIcompressiontype                       None
# GOSSIgainmode                              None
# GOSSIobstruction                           None
# GOSSIframeduration                         None
# GOSSIimageid                               None
# GOSSIobservationid                         None
# NHLORRIbinningmode                         None
# NHLORRIinstrumentcompressiontype           None
# NHMVICinstrumentcompressiontype            None
# VGISScamera                                None
# VGISSfilter                                None
# VGISSfilternumber                          None
# VGISSshuttermode                           None
# VGISSeditmode                              None
# VGISSgainmode                              None
# VGISSscanmode                              None
# VGISSimageid                               None
# VGISSusablelines                           None
# VGISSusablesamples                         None
#
#                                                           fieldid1  \
# planet                                                      planet
# target                                                      target
# targetclass                                            targetclass
# mission                                                    mission
# insthost                                                  insthost
# instrument                                              instrument
# observationtype                                    observationtype
# time                                                         time1
# observationduration                            observationduration
# quantity                                                  quantity
# rightasc                                                 rightasc1
# declination                                           declination1
# ringobsid                                                ringobsid
# volumeid                                                  volumeid
# datasetid                                                datasetid
# productid                                                productid
# productcreationtime                            productcreationtime
# primaryfilespec                                    primaryfilespec
# opusid                                                      opusid
# note                                                          note
# duration                                                  duration
# greaterpixelsize                                  greaterpixelsize
# lesserpixelsize                                    lesserpixelsize
# levels                                                      levels
# imagetype                                                imagetype
# wavelength                                             wavelength1
# waveres                                                   waveres1
# waveno                                                     waveno1
# wavenores                                               wavenores1
# specflag                                                  specflag
# ...                                                            ...
# COVIMSvisexposure                                COVIMSvisexposure
# COVIMSirsamplingmode                          COVIMSirsamplingmode
# COVIMSirexposure                                  COVIMSirexposure
# COVIMSswathwidth                                  COVIMSswathwidth
# COVIMSswathlength                                COVIMSswathlength
# COVIMSspectralsumming                        COVIMSspectralsumming
# COVIMSspectralediting                        COVIMSspectralediting
# COVIMSinstrumentmode                          COVIMSinstrumentmode
# COVIMSstartracking                              COVIMSstartracking
# GOSSIfilter                                            GOSSIfilter
# GOSSIfilternumber                                GOSSIfilternumber
# GOSSIcompressiontype                          GOSSIcompressiontype
# GOSSIgainmode                                        GOSSIgainmode
# GOSSIobstruction                                  GOSSIobstruction
# GOSSIframeduration                              GOSSIframeduration
# GOSSIimageid                                          GOSSIimageid
# GOSSIobservationid                              GOSSIobservationid
# NHLORRIbinningmode                              NHLORRIbinningmode
# NHLORRIinstrumentcompressiontype  NHLORRIinstrumentcompressiontype
# NHMVICinstrumentcompressiontype    NHMVICinstrumentcompressiontype
# VGISScamera                                            VGISScamera
# VGISSfilter                                            VGISSfilter
# VGISSfilternumber                                VGISSfilternumber
# VGISSshuttermode                                  VGISSshuttermode
# VGISSeditmode                                        VGISSeditmode
# VGISSgainmode                                        VGISSgainmode
# VGISSscanmode                                        VGISSscanmode
# VGISSimageid                                          VGISSimageid
# VGISSusablelines                                  VGISSusablelines
# VGISSusablesamples                              VGISSusablesamples
#
#                                       fieldid2  \
# planet                                    None
# target                                    None
# targetclass                               None
# mission                                   None
# insthost                                  None
# instrument                                None
# observationtype                           None
# time                                     time2
# observationduration                       None
# quantity                                  None
# rightasc                             rightasc2
# declination                       declination2
# ringobsid                                 None
# volumeid                                  None
# datasetid                                 None
# productid                                 None
# productcreationtime                       None
# primaryfilespec                           None
# opusid                                    None
# note                                      None
# duration                                  None
# greaterpixelsize                          None
# lesserpixelsize                           None
# levels                                    None
# imagetype                                 None
# wavelength                         wavelength2
# waveres                               waveres2
# waveno                                 waveno2
# wavenores                           wavenores2
# specflag                                  None
# ...                                        ...
# COVIMSvisexposure                         None
# COVIMSirsamplingmode                      None
# COVIMSirexposure                          None
# COVIMSswathwidth                          None
# COVIMSswathlength                         None
# COVIMSspectralsumming                     None
# COVIMSspectralediting                     None
# COVIMSinstrumentmode                      None
# COVIMSstartracking                        None
# GOSSIfilter                               None
# GOSSIfilternumber                         None
# GOSSIcompressiontype                      None
# GOSSIgainmode                             None
# GOSSIobstruction                          None
# GOSSIframeduration                        None
# GOSSIimageid                              None
# GOSSIobservationid                        None
# NHLORRIbinningmode                        None
# NHLORRIinstrumentcompressiontype          None
# NHMVICinstrumentcompressiontype           None
# VGISScamera                               None
# VGISSfilter                               None
# VGISSfilternumber                         None
# VGISSshuttermode                          None
# VGISSeditmode                             None
# VGISSgainmode                             None
# VGISSscanmode                             None
# VGISSimageid                              None
# VGISSusablelines                          None
# VGISSusablesamples                        None
#
#                                                                        full_label1  \
# planet                                                                      Planet
# target                                                        Intended Target Name
# targetclass                                                   Nominal Target Class
# mission                                                                    Mission
# insthost                                                      Instrument Host Name
# instrument                                                         Instrument Name
# observationtype                                                   Observation Type
# time                                                        Observation Start Time
# observationduration                                           Observation Duration
# quantity                                                      Measurement Quantity
# rightasc                                                     Right Ascension (Min)
# declination                                                      Declination (Min)
# ringobsid                                                              RING OBS ID
# volumeid                                                                 Volume ID
# datasetid                                                              Data Set ID
# productid                                                               Product ID
# productcreationtime                                          Product Creation Time
# primaryfilespec                                                  Primary File Spec
# opusid                                                                     OPUS ID
# note                                                                          Note
# duration                                                         Exposure Duration
# greaterpixelsize                                            Greater Size in Pixels
# lesserpixelsize                                              Lesser Size in Pixels
# levels                                                            Intensity Levels
# imagetype                                                               Image Type
# wavelength                                                        Wavelength (Min)
# waveres                                                Wavelength Resolution (Min)
# waveno                                                            Wavenumber (Min)
# wavenores                                              Wavenumber Resolution (Min)
# specflag                                                 Spectral Information Flag
# ...                                                                            ...
# COVIMSvisexposure                                      VIS Exposure [Cassini VIMS]
# COVIMSirsamplingmode                               IR Sampling Mode [Cassini VIMS]
# COVIMSirexposure                                        IR Exposure [Cassini VIMS]
# COVIMSswathwidth                                        Swath Width [Cassini VIMS]
# COVIMSswathlength                                      Swath Length [Cassini VIMS]
# COVIMSspectralsumming                              Spectral Summing [Cassini VIMS]
# COVIMSspectralediting                              Spectral Editing [Cassini VIMS]
# COVIMSinstrumentmode                                Instrument Mode [Cassini VIMS]
# COVIMSstartracking                                    Star Tracking [Cassini VIMS]
# GOSSIfilter                                              Filter Name [Galileo SSI]
# GOSSIfilternumber                                      Filter Number [Galileo SSI]
# GOSSIcompressiontype                                Compression Type [Galileo SSI]
# GOSSIgainmode                                              Gain Mode [Galileo SSI]
# GOSSIobstruction                                         Obstruction [Galileo SSI]
# GOSSIframeduration                                    Frame Duration [Galileo SSI]
# GOSSIimageid                                                Image ID [Galileo SSI]
# GOSSIobservationid                                    Observation ID [Galileo SSI]
# NHLORRIbinningmode                               Binning Mode [New Horizons LORRI]
# NHLORRIinstrumentcompressiontype  Instrument Compression Type [New Horizons LORRI]
# NHMVICinstrumentcompressiontype    Instrument Compression Type [New Horizons MVIC]
# VGISScamera                                                   Camera [Voyager ISS]
# VGISSfilter                                              Filter Name [Voyager ISS]
# VGISSfilternumber                                      Filter Number [Voyager ISS]
# VGISSshuttermode                                        Shutter Mode [Voyager ISS]
# VGISSeditmode                                              Edit Mode [Voyager ISS]
# VGISSgainmode                                              Gain Mode [Voyager ISS]
# VGISSscanmode                                              Scan Mode [Voyager ISS]
# VGISSimageid                                                Image ID [Voyager ISS]
# VGISSusablelines                                        Usable Lines [Voyager ISS]
# VGISSusablesamples                                    Usable Samples [Voyager ISS]
#
#                                                   full_label2  \
# planet                                                   None
# target                                                   None
# targetclass                                              None
# mission                                                  None
# insthost                                                 None
# instrument                                               None
# observationtype                                          None
# time                                    Observation Stop Time
# observationduration                                      None
# quantity                                                 None
# rightasc                                Right Ascension (Max)
# declination                                 Declination (Max)
# ringobsid                                                None
# volumeid                                                 None
# datasetid                                                None
# productid                                                None
# productcreationtime                                      None
# primaryfilespec                                          None
# opusid                                                   None
# note                                                     None
# duration                                                 None
# greaterpixelsize                                         None
# lesserpixelsize                                          None
# levels                                                   None
# imagetype                                                None
# wavelength                                   Wavelength (Max)
# waveres                           Wavelength Resolution (Max)
# waveno                                       Wavenumber (Max)
# wavenores                         Wavenumber Resolution (Max)
# specflag                                                 None
# ...                                                       ...
# COVIMSvisexposure                                        None
# COVIMSirsamplingmode                                     None
# COVIMSirexposure                                         None
# COVIMSswathwidth                                         None
# COVIMSswathlength                                        None
# COVIMSspectralsumming                                    None
# COVIMSspectralediting                                    None
# COVIMSinstrumentmode                                     None
# COVIMSstartracking                                       None
# GOSSIfilter                                              None
# GOSSIfilternumber                                        None
# GOSSIcompressiontype                                     None
# GOSSIgainmode                                            None
# GOSSIobstruction                                         None
# GOSSIframeduration                                       None
# GOSSIimageid                                             None
# GOSSIobservationid                                       None
# NHLORRIbinningmode                                       None
# NHLORRIinstrumentcompressiontype                         None
# NHMVICinstrumentcompressiontype                          None
# VGISScamera                                              None
# VGISSfilter                                              None
# VGISSfilternumber                                        None
# VGISSshuttermode                                         None
# VGISSeditmode                                            None
# VGISSgainmode                                            None
# VGISSscanmode                                            None
# VGISSimageid                                             None
# VGISSusablelines                                         None
# VGISSusablesamples                                       None
#
#                                                                  full_search_label  \
# planet                                                            Planet [General]
# target                                              Intended Target Name [General]
# targetclass                                         Nominal Target Class [General]
# mission                                                          Mission [General]
# insthost                                            Instrument Host Name [General]
# instrument                                               Instrument Name [General]
# observationtype                                         Observation Type [General]
# time                                                    Observation Time [General]
# observationduration                                 Observation Duration [General]
# quantity                                            Measurement Quantity [General]
# rightasc                                                 Right Ascension [General]
# declination                                                  Declination [General]
# ringobsid                                                    RING OBS ID [General]
# volumeid                                                           Volume ID [PDS]
# datasetid                                                        Data Set ID [PDS]
# productid                                                         Product ID [PDS]
# productcreationtime                                    Product Creation Time [PDS]
# primaryfilespec                                            Primary File Spec [PDS]
# opusid                                                               OPUS ID [PDS]
# note                                                                    Note [PDS]
# duration                                                 Exposure Duration [Image]
# greaterpixelsize                                    Greater Size in Pixels [Image]
# lesserpixelsize                                      Lesser Size in Pixels [Image]
# levels                                                    Intensity Levels [Image]
# imagetype                                                       Image Type [Image]
# wavelength                                                 Wavelength [Wavelength]
# waveres                                         Wavelength Resolution [Wavelength]
# waveno                                                     Wavenumber [Wavelength]
# wavenores                                       Wavenumber Resolution [Wavelength]
# specflag                                    Spectral Information Flag [Wavelength]
# ...                                                                            ...
# COVIMSvisexposure                                      VIS Exposure [Cassini VIMS]
# COVIMSirsamplingmode                               IR Sampling Mode [Cassini VIMS]
# COVIMSirexposure                                        IR Exposure [Cassini VIMS]
# COVIMSswathwidth                                        Swath Width [Cassini VIMS]
# COVIMSswathlength                                      Swath Length [Cassini VIMS]
# COVIMSspectralsumming                              Spectral Summing [Cassini VIMS]
# COVIMSspectralediting                              Spectral Editing [Cassini VIMS]
# COVIMSinstrumentmode                                Instrument Mode [Cassini VIMS]
# COVIMSstartracking                                    Star Tracking [Cassini VIMS]
# GOSSIfilter                                              Filter Name [Galileo SSI]
# GOSSIfilternumber                                      Filter Number [Galileo SSI]
# GOSSIcompressiontype                                Compression Type [Galileo SSI]
# GOSSIgainmode                                              Gain Mode [Galileo SSI]
# GOSSIobstruction                                         Obstruction [Galileo SSI]
# GOSSIframeduration                                    Frame Duration [Galileo SSI]
# GOSSIimageid                                                Image ID [Galileo SSI]
# GOSSIobservationid                                    Observation ID [Galileo SSI]
# NHLORRIbinningmode                               Binning Mode [New Horizons LORRI]
# NHLORRIinstrumentcompressiontype  Instrument Compression Type [New Horizons LORRI]
# NHMVICinstrumentcompressiontype    Instrument Compression Type [New Horizons MVIC]
# VGISScamera                                                   Camera [Voyager ISS]
# VGISSfilter                                              Filter Name [Voyager ISS]
# VGISSfilternumber                                      Filter Number [Voyager ISS]
# VGISSshuttermode                                        Shutter Mode [Voyager ISS]
# VGISSeditmode                                              Edit Mode [Voyager ISS]
# VGISSgainmode                                              Gain Mode [Voyager ISS]
# VGISSscanmode                                              Scan Mode [Voyager ISS]
# VGISSimageid                                                Image ID [Voyager ISS]
# VGISSusablelines                                        Usable Lines [Voyager ISS]
# VGISSusablesamples                                    Usable Samples [Voyager ISS]
#
#                                                        label1  \
# planet                                                 Planet
# target                                   Intended Target Name
# targetclass                              Nominal Target Class
# mission                                               Mission
# insthost                                 Instrument Host Name
# instrument                                    Instrument Name
# observationtype                              Observation Type
# time                                   Observation Start Time
# observationduration                      Observation Duration
# quantity                                 Measurement Quantity
# rightasc                                Right Ascension (Min)
# declination                                 Declination (Min)
# ringobsid                                         RING OBS ID
# volumeid                                            Volume ID
# datasetid                                         Data Set ID
# productid                                          Product ID
# productcreationtime                     Product Creation Time
# primaryfilespec                             Primary File Spec
# opusid                                                OPUS ID
# note                                                     Note
# duration                                    Exposure Duration
# greaterpixelsize                       Greater Size in Pixels
# lesserpixelsize                         Lesser Size in Pixels
# levels                                       Intensity Levels
# imagetype                                          Image Type
# wavelength                                   Wavelength (Min)
# waveres                           Wavelength Resolution (Min)
# waveno                                       Wavenumber (Min)
# wavenores                         Wavenumber Resolution (Min)
# specflag                            Spectral Information Flag
# ...                                                       ...
# COVIMSvisexposure                                VIS Exposure
# COVIMSirsamplingmode                         IR Sampling Mode
# COVIMSirexposure                                  IR Exposure
# COVIMSswathwidth                                  Swath Width
# COVIMSswathlength                                Swath Length
# COVIMSspectralsumming                        Spectral Summing
# COVIMSspectralediting                        Spectral Editing
# COVIMSinstrumentmode                          Instrument Mode
# COVIMSstartracking                              Star Tracking
# GOSSIfilter                                       Filter Name
# GOSSIfilternumber                               Filter Number
# GOSSIcompressiontype                         Compression Type
# GOSSIgainmode                                       Gain Mode
# GOSSIobstruction                                  Obstruction
# GOSSIframeduration                             Frame Duration
# GOSSIimageid                                         Image ID
# GOSSIobservationid                             Observation ID
# NHLORRIbinningmode                               Binning Mode
# NHLORRIinstrumentcompressiontype  Instrument Compression Type
# NHMVICinstrumentcompressiontype   Instrument Compression Type
# VGISScamera                                            Camera
# VGISSfilter                                       Filter Name
# VGISSfilternumber                               Filter Number
# VGISSshuttermode                                 Shutter Mode
# VGISSeditmode                                       Edit Mode
# VGISSgainmode                                       Gain Mode
# VGISSscanmode                                       Scan Mode
# VGISSimageid                                         Image ID
# VGISSusablelines                                 Usable Lines
# VGISSusablesamples                             Usable Samples
#
#                                                        label2  \
# planet                                                   None
# target                                                   None
# targetclass                                              None
# mission                                                  None
# insthost                                                 None
# instrument                                               None
# observationtype                                          None
# time                                    Observation Stop Time
# observationduration                                      None
# quantity                                                 None
# rightasc                                Right Ascension (Max)
# declination                                 Declination (Max)
# ringobsid                                                None
# volumeid                                                 None
# datasetid                                                None
# productid                                                None
# productcreationtime                                      None
# primaryfilespec                                          None
# opusid                                                   None
# note                                                     None
# duration                                                 None
# greaterpixelsize                                         None
# lesserpixelsize                                          None
# levels                                                   None
# imagetype                                                None
# wavelength                                   Wavelength (Max)
# waveres                           Wavelength Resolution (Max)
# waveno                                       Wavenumber (Max)
# wavenores                         Wavenumber Resolution (Max)
# specflag                                                 None
# ...                                                       ...
# COVIMSvisexposure                                        None
# COVIMSirsamplingmode                                     None
# COVIMSirexposure                                         None
# COVIMSswathwidth                                         None
# COVIMSswathlength                                        None
# COVIMSspectralsumming                                    None
# COVIMSspectralediting                                    None
# COVIMSinstrumentmode                                     None
# COVIMSstartracking                                       None
# GOSSIfilter                                              None
# GOSSIfilternumber                                        None
# GOSSIcompressiontype                                     None
# GOSSIgainmode                                            None
# GOSSIobstruction                                         None
# GOSSIframeduration                                       None
# GOSSIimageid                                             None
# GOSSIobservationid                                       None
# NHLORRIbinningmode                                       None
# NHLORRIinstrumentcompressiontype                         None
# NHMVICinstrumentcompressiontype                          None
# VGISScamera                                              None
# VGISSfilter                                              None
# VGISSfilternumber                                        None
# VGISSshuttermode                                         None
# VGISSeditmode                                            None
# VGISSgainmode                                            None
# VGISSscanmode                                            None
# VGISSimageid                                             None
# VGISSusablelines                                         None
# VGISSusablesamples                                       None
#
#                                                    search_fieldid1  \
# planet                                                      planet
# target                                                      target
# targetclass                                            targetclass
# mission                                                    mission
# insthost                                                  insthost
# instrument                                              instrument
# observationtype                                    observationtype
# time                                                         time1
# observationduration                           observationduration1
# quantity                                                  quantity
# rightasc                                                 rightasc1
# declination                                           declination1
# ringobsid                                                ringobsid
# volumeid                                                  volumeid
# datasetid                                                datasetid
# productid                                                productid
# productcreationtime                           productcreationtime1
# primaryfilespec                                    primaryfilespec
# opusid                                                      opusid
# note                                                          note
# duration                                                 duration1
# greaterpixelsize                                 greaterpixelsize1
# lesserpixelsize                                   lesserpixelsize1
# levels                                                     levels1
# imagetype                                                imagetype
# wavelength                                             wavelength1
# waveres                                                   waveres1
# waveno                                                     waveno1
# wavenores                                               wavenores1
# specflag                                                  specflag
# ...                                                            ...
# COVIMSvisexposure                               COVIMSvisexposure1
# COVIMSirsamplingmode                          COVIMSirsamplingmode
# COVIMSirexposure                                 COVIMSirexposure1
# COVIMSswathwidth                                 COVIMSswathwidth1
# COVIMSswathlength                               COVIMSswathlength1
# COVIMSspectralsumming                        COVIMSspectralsumming
# COVIMSspectralediting                        COVIMSspectralediting
# COVIMSinstrumentmode                          COVIMSinstrumentmode
# COVIMSstartracking                              COVIMSstartracking
# GOSSIfilter                                            GOSSIfilter
# GOSSIfilternumber                                GOSSIfilternumber
# GOSSIcompressiontype                          GOSSIcompressiontype
# GOSSIgainmode                                        GOSSIgainmode
# GOSSIobstruction                                  GOSSIobstruction
# GOSSIframeduration                              GOSSIframeduration
# GOSSIimageid                                          GOSSIimageid
# GOSSIobservationid                              GOSSIobservationid
# NHLORRIbinningmode                              NHLORRIbinningmode
# NHLORRIinstrumentcompressiontype  NHLORRIinstrumentcompressiontype
# NHMVICinstrumentcompressiontype    NHMVICinstrumentcompressiontype
# VGISScamera                                            VGISScamera
# VGISSfilter                                            VGISSfilter
# VGISSfilternumber                                VGISSfilternumber
# VGISSshuttermode                                  VGISSshuttermode
# VGISSeditmode                                        VGISSeditmode
# VGISSgainmode                                        VGISSgainmode
# VGISSscanmode                                        VGISSscanmode
# VGISSimageid                                          VGISSimageid
# VGISSusablelines                                 VGISSusablelines1
# VGISSusablesamples                             VGISSusablesamples1
#
#                                        search_fieldid2  \
# planet                                            None
# target                                            None
# targetclass                                       None
# mission                                           None
# insthost                                          None
# instrument                                        None
# observationtype                                   None
# time                                             time2
# observationduration               observationduration2
# quantity                                          None
# rightasc                                     rightasc2
# declination                               declination2
# ringobsid                                         None
# volumeid                                          None
# datasetid                                         None
# productid                                         None
# productcreationtime               productcreationtime2
# primaryfilespec                                   None
# opusid                                            None
# note                                              None
# duration                                     duration2
# greaterpixelsize                     greaterpixelsize2
# lesserpixelsize                       lesserpixelsize2
# levels                                         levels2
# imagetype                                         None
# wavelength                                 wavelength2
# waveres                                       waveres2
# waveno                                         waveno2
# wavenores                                   wavenores2
# specflag                                          None
# ...                                                ...
# COVIMSvisexposure                   COVIMSvisexposure2
# COVIMSirsamplingmode                              None
# COVIMSirexposure                     COVIMSirexposure2
# COVIMSswathwidth                     COVIMSswathwidth2
# COVIMSswathlength                   COVIMSswathlength2
# COVIMSspectralsumming                             None
# COVIMSspectralediting                             None
# COVIMSinstrumentmode                              None
# COVIMSstartracking                                None
# GOSSIfilter                                       None
# GOSSIfilternumber                                 None
# GOSSIcompressiontype                              None
# GOSSIgainmode                                     None
# GOSSIobstruction                                  None
# GOSSIframeduration                                None
# GOSSIimageid                                      None
# GOSSIobservationid                                None
# NHLORRIbinningmode                                None
# NHLORRIinstrumentcompressiontype                  None
# NHMVICinstrumentcompressiontype                   None
# VGISScamera                                       None
# VGISSfilter                                       None
# VGISSfilternumber                                 None
# VGISSshuttermode                                  None
# VGISSeditmode                                     None
# VGISSgainmode                                     None
# VGISSscanmode                                     None
# VGISSimageid                                      None
# VGISSusablelines                     VGISSusablelines2
# VGISSusablesamples                 VGISSusablesamples2
#
#                                                  search_label  single_value  \
# planet                                                 Planet          True
# target                                   Intended Target Name          True
# targetclass                              Nominal Target Class          True
# mission                                               Mission          True
# insthost                                 Instrument Host Name          True
# instrument                                    Instrument Name          True
# observationtype                              Observation Type          True
# time                                         Observation Time         False
# observationduration                      Observation Duration          True
# quantity                                 Measurement Quantity          True
# rightasc                                      Right Ascension         False
# declination                                       Declination         False
# ringobsid                                         RING OBS ID          True
# volumeid                                            Volume ID          True
# datasetid                                         Data Set ID          True
# productid                                          Product ID          True
# productcreationtime                     Product Creation Time          True
# primaryfilespec                             Primary File Spec          True
# opusid                                                OPUS ID          True
# note                                                     Note          True
# duration                                    Exposure Duration          True
# greaterpixelsize                       Greater Size in Pixels          True
# lesserpixelsize                         Lesser Size in Pixels          True
# levels                                       Intensity Levels          True
# imagetype                                          Image Type          True
# wavelength                                         Wavelength         False
# waveres                                 Wavelength Resolution         False
# waveno                                             Wavenumber         False
# wavenores                               Wavenumber Resolution         False
# specflag                            Spectral Information Flag          True
# ...                                                       ...           ...
# COVIMSvisexposure                                VIS Exposure          True
# COVIMSirsamplingmode                         IR Sampling Mode          True
# COVIMSirexposure                                  IR Exposure          True
# COVIMSswathwidth                                  Swath Width          True
# COVIMSswathlength                                Swath Length          True
# COVIMSspectralsumming                        Spectral Summing          True
# COVIMSspectralediting                        Spectral Editing          True
# COVIMSinstrumentmode                          Instrument Mode          True
# COVIMSstartracking                              Star Tracking          True
# GOSSIfilter                                       Filter Name          True
# GOSSIfilternumber                               Filter Number          True
# GOSSIcompressiontype                         Compression Type          True
# GOSSIgainmode                                       Gain Mode          True
# GOSSIobstruction                                  Obstruction          True
# GOSSIframeduration                             Frame Duration          True
# GOSSIimageid                                         Image ID          True
# GOSSIobservationid                             Observation ID          True
# NHLORRIbinningmode                               Binning Mode          True
# NHLORRIinstrumentcompressiontype  Instrument Compression Type          True
# NHMVICinstrumentcompressiontype   Instrument Compression Type          True
# VGISScamera                                            Camera          True
# VGISSfilter                                       Filter Name          True
# VGISSfilternumber                               Filter Number          True
# VGISSshuttermode                                 Shutter Mode          True
# VGISSeditmode                                       Edit Mode          True
# VGISSgainmode                                       Gain Mode          True
# VGISSscanmode                                       Scan Mode          True
# VGISSimageid                                         Image ID          True
# VGISSusablelines                                 Usable Lines          True
# VGISSusablesamples                             Usable Samples          True
#
#                                              type
# planet                                   multiple
# target                                   multiple
# targetclass                              multiple
# mission                                  multiple
# insthost                                 multiple
# instrument                               multiple
# observationtype                          multiple
# time                                   range_time
# observationduration                   range_float
# quantity                                 multiple
# rightasc                          range_longitude
# declination                           range_float
# ringobsid                                  string
# volumeid                                   string
# datasetid                                  string
# productid                                  string
# productcreationtime                    range_time
# primaryfilespec                            string
# opusid                                     string
# note                                       string
# duration                              range_float
# greaterpixelsize                    range_integer
# lesserpixelsize                     range_integer
# levels                              range_integer
# imagetype                                multiple
# wavelength                            range_float
# waveres                               range_float
# waveno                                range_float
# wavenores                             range_float
# specflag                                 multiple
# ...                                           ...
# COVIMSvisexposure                     range_float
# COVIMSirsamplingmode                     multiple
# COVIMSirexposure                      range_float
# COVIMSswathwidth                    range_integer
# COVIMSswathlength                   range_integer
# COVIMSspectralsumming                    multiple
# COVIMSspectralediting                    multiple
# COVIMSinstrumentmode                     multiple
# COVIMSstartracking                       multiple
# GOSSIfilter                              multiple
# GOSSIfilternumber                        multiple
# GOSSIcompressiontype                     multiple
# GOSSIgainmode                            multiple
# GOSSIobstruction                         multiple
# GOSSIframeduration                       multiple
# GOSSIimageid                               string
# GOSSIobservationid                         string
# NHLORRIbinningmode                       multiple
# NHLORRIinstrumentcompressiontype         multiple
# NHMVICinstrumentcompressiontype          multiple
# VGISScamera                              multiple
# VGISSfilter                              multiple
# VGISSfilternumber                        multiple
# VGISSshuttermode                         multiple
# VGISSeditmode                            multiple
# VGISSgainmode                            multiple
# VGISSscanmode                            multiple
# VGISSimageid                               string
# VGISSusablelines                    range_integer
# VGISSusablesamples                  range_integer
#
# [2177 rows x 15 columns]

# %% [markdown]
# # Extract the list of surface geometry targets and the suffixes for surface geometry fields.

# %%
sgt=O.surfacegeo_targets

# %%
sgt
# Out:
# {'Adrastea': 'adrastea',
#  'Aegaeon': 'aegaeon',
#  'Albiorix': 'albiorix',
#  'Amalthea': 'amalthea',
#  'Anthe': 'anthe',
#  'Ariel': 'ariel',
#  'Atlas': 'atlas',
#  'Bebhionn': 'bebhionn',
#  'Belinda': 'belinda',
#  'Bergelmir': 'bergelmir',
#  'Bestla': 'bestla',
#  'Bianca': 'bianca',
#  'Callirrhoe': 'callirrhoe',
#  'Callisto': 'callisto',
#  'Calypso': 'calypso',
#  'Charon': 'charon',
#  'Cordelia': 'cordelia',
#  'Cressida': 'cressida',
#  'Cupid': 'cupid',
#  'Daphnis': 'daphnis',
#  'Desdemona': 'desdemona',
#  'Despina': 'despina',
#  'Dione': 'dione',
#  'Earth': 'earth',
#  'Elara': 'elara',
#  'Enceladus': 'enceladus',
#  'Epimetheus': 'epimetheus',
#  'Erriapus': 'erriapus',
#  'Europa': 'europa',
#  'Fornjot': 'fornjot',
#  'Galatea': 'galatea',
#  'Ganymede': 'ganymede',
#  'Greip': 'greip',
#  'Hati': 'hati',
#  'Helene': 'helene',
#  'Himalia': 'himalia',
#  'Hydra': 'hydra',
#  'Hyperion': 'hyperion',
#  'Iapetus': 'iapetus',
#  'Ijiraq': 'ijiraq',
#  'Io': 'io',
#  'Janus': 'janus',
#  'Jarnsaxa': 'jarnsaxa',
#  'Juliet': 'juliet',
#  'Jupiter': 'jupiter',
#  'Kari': 'kari',
#  'Kerberos': 'kerberos',
#  'Kiviuq': 'kiviuq',
#  'Larissa': 'larissa',
#  'Loge': 'loge',
#  'Mab': 'mab',
#  'Methone': 'methone',
#  'Metis': 'metis',
#  'Mimas': 'mimas',
#  'Miranda': 'miranda',
#  'Moon': 'moon',
#  'Mundilfari': 'mundilfari',
#  'Naiad': 'naiad',
#  'Narvi': 'narvi',
#  'Neptune': 'neptune',
#  'Nereid': 'nereid',
#  'Nix': 'nix',
#  'Oberon': 'oberon',
#  'Ophelia': 'ophelia',
#  'Paaliaq': 'paaliaq',
#  'Pallene': 'pallene',
#  'Pan': 'pan',
#  'Pandora': 'pandora',
#  'Perdita': 'perdita',
#  'Phoebe': 'phoebe',
#  'Pluto': 'pluto',
#  'Polydeuces': 'polydeuces',
#  'Portia': 'portia',
#  'Prometheus': 'prometheus',
#  'Proteus': 'proteus',
#  'Puck': 'puck',
#  'Rhea': 'rhea',
#  'Rosalind': 'rosalind',
#  'S/2004 S 12': 's2004s12',
#  'S/2004 S 13': 's2004s13',
#  'Saturn': 'saturn',
#  'Siarnaq': 'siarnaq',
#  'Skathi': 'skathi',
#  'Skoll': 'skoll',
#  'Styx': 'styx',
#  'Surtur': 'surtur',
#  'Suttungr': 'suttungr',
#  'Tarqeq': 'tarqeq',
#  'Tarvos': 'tarvos',
#  'Telesto': 'telesto',
#  'Tethys': 'tethys',
#  'Thalassa': 'thalassa',
#  'Thebe': 'thebe',
#  'Thrymr': 'thrymr',
#  'Titan': 'titan',
#  'Titania': 'titania',
#  'Triton': 'triton',
#  'Umbriel': 'umbriel',
#  'Uranus': 'uranus',
#  'Ymir': 'ymir'}

# %%
sgf=O.surfacegeo_fields

# %%
sgf.keys()
# Out:
# dict_keys(['planetographiclatitude', 'subsolarplanetographiclatitude', 'subobserverplanetographiclatitude', 'planetocentriclatitude', 'subsolarplanetocentriclatitude', 'subobserverplanetocentriclatitude', 'IAUwestlongitude', 'subsolarIAUlongitude', 'subobserverIAUlongitude', 'observerlongitude', 'rangetobody', 'centerdistance', 'finestresolution', 'coarsestresolution', 'centerresolution', 'centerphaseangle', 'phase', 'incidence', 'emission', 'solarhourangle'])

# %%
sgf['planetographiclatitude']
# Out:
# {'available_units': ['degrees', 'hourangle', 'radians'],
#  'category': 'Adrastea Surface Geometry Constraints',
#  'default_units': 'degrees',
#  'fieldid1': 'SURFACEGEOadrastea_planetographiclatitude1',
#  'fieldid2': 'SURFACEGEOadrastea_planetographiclatitude2',
#  'full_label1': 'Observed Planetographic Latitude (Min) [Adrastea]',
#  'full_label2': 'Observed Planetographic Latitude (Max) [Adrastea]',
#  'full_search_label': 'Observed Planetographic Latitude [Adrastea]',
#  'label1': 'Observed Planetographic Latitude (Min)',
#  'label2': 'Observed Planetographic Latitude (Max)',
#  'search_fieldid1': 'SURFACEGEOadrastea_planetographiclatitude1',
#  'search_fieldid2': 'SURFACEGEOadrastea_planetographiclatitude2',
#  'search_label': 'Observed Planetographic Latitude',
#  'single_value': False,
#  'type': 'range_float'}

# %%
sgfdf=O.surfacegeo_fields_as_df

# %%
sgfdf
# Out:
#                                                                      available_units  \
# planetographiclatitude                                 [degrees, hourangle, radians]
# subsolarplanetographiclatitude                         [degrees, hourangle, radians]
# subobserverplanetographiclatitude                      [degrees, hourangle, radians]
# planetocentriclatitude                                 [degrees, hourangle, radians]
# subsolarplanetocentriclatitude                         [degrees, hourangle, radians]
# subobserverplanetocentriclatitude                      [degrees, hourangle, radians]
# IAUwestlongitude                                       [degrees, hourangle, radians]
# subsolarIAUlongitude                                   [degrees, hourangle, radians]
# subobserverIAUlongitude                                [degrees, hourangle, radians]
# observerlongitude                                      [degrees, hourangle, radians]
# rangetobody                        [km, m, jupiterradii, saturnradii, neptuneradi...
# centerdistance                     [km, m, jupiterradii, saturnradii, neptuneradi...
# finestresolution                                                 [km/pixel, m/pixel]
# coarsestresolution                                               [km/pixel, m/pixel]
# centerresolution                                                 [km/pixel, m/pixel]
# centerphaseangle                                       [degrees, hourangle, radians]
# phase                                                  [degrees, hourangle, radians]
# incidence                                              [degrees, hourangle, radians]
# emission                                               [degrees, hourangle, radians]
# solarhourangle                                         [degrees, hourangle, radians]
#
#                                                                 category  \
# planetographiclatitude             Adrastea Surface Geometry Constraints
# subsolarplanetographiclatitude     Adrastea Surface Geometry Constraints
# subobserverplanetographiclatitude  Adrastea Surface Geometry Constraints
# planetocentriclatitude             Adrastea Surface Geometry Constraints
# subsolarplanetocentriclatitude     Adrastea Surface Geometry Constraints
# subobserverplanetocentriclatitude  Adrastea Surface Geometry Constraints
# IAUwestlongitude                   Adrastea Surface Geometry Constraints
# subsolarIAUlongitude               Adrastea Surface Geometry Constraints
# subobserverIAUlongitude            Adrastea Surface Geometry Constraints
# observerlongitude                  Adrastea Surface Geometry Constraints
# rangetobody                        Adrastea Surface Geometry Constraints
# centerdistance                     Adrastea Surface Geometry Constraints
# finestresolution                   Adrastea Surface Geometry Constraints
# coarsestresolution                 Adrastea Surface Geometry Constraints
# centerresolution                   Adrastea Surface Geometry Constraints
# centerphaseangle                   Adrastea Surface Geometry Constraints
# phase                              Adrastea Surface Geometry Constraints
# incidence                          Adrastea Surface Geometry Constraints
# emission                           Adrastea Surface Geometry Constraints
# solarhourangle                     Adrastea Surface Geometry Constraints
#
#                                   default_units  \
# planetographiclatitude                  degrees
# subsolarplanetographiclatitude          degrees
# subobserverplanetographiclatitude       degrees
# planetocentriclatitude                  degrees
# subsolarplanetocentriclatitude          degrees
# subobserverplanetocentriclatitude       degrees
# IAUwestlongitude                        degrees
# subsolarIAUlongitude                    degrees
# subobserverIAUlongitude                 degrees
# observerlongitude                       degrees
# rangetobody                                  km
# centerdistance                               km
# finestresolution                       km/pixel
# coarsestresolution                     km/pixel
# centerresolution                       km/pixel
# centerphaseangle                        degrees
# phase                                   degrees
# incidence                               degrees
# emission                                degrees
# solarhourangle                          degrees
#
#                                                                             fieldid1  \
# planetographiclatitude                    SURFACEGEOadrastea_planetographiclatitude1
# subsolarplanetographiclatitude     SURFACEGEOadrastea_subsolarplanetographiclatitude
# subobserverplanetographiclatitude  SURFACEGEOadrastea_subobserverplanetographicla...
# planetocentriclatitude                    SURFACEGEOadrastea_planetocentriclatitude1
# subsolarplanetocentriclatitude     SURFACEGEOadrastea_subsolarplanetocentriclatitude
# subobserverplanetocentriclatitude  SURFACEGEOadrastea_subobserverplanetocentricla...
# IAUwestlongitude                                SURFACEGEOadrastea_IAUwestlongitude1
# subsolarIAUlongitude                         SURFACEGEOadrastea_subsolarIAUlongitude
# subobserverIAUlongitude                   SURFACEGEOadrastea_subobserverIAUlongitude
# observerlongitude                              SURFACEGEOadrastea_observerlongitude1
# rangetobody                                          SURFACEGEOadrastea_rangetobody1
# centerdistance                                     SURFACEGEOadrastea_centerdistance
# finestresolution                                SURFACEGEOadrastea_finestresolution1
# coarsestresolution                            SURFACEGEOadrastea_coarsestresolution1
# centerresolution                                 SURFACEGEOadrastea_centerresolution
# centerphaseangle                                 SURFACEGEOadrastea_centerphaseangle
# phase                                                      SURFACEGEOadrastea_phase1
# incidence                                              SURFACEGEOadrastea_incidence1
# emission                                                SURFACEGEOadrastea_emission1
# solarhourangle                                    SURFACEGEOadrastea_solarhourangle1
#
#                                                                      fieldid2  \
# planetographiclatitude             SURFACEGEOadrastea_planetographiclatitude2
# subsolarplanetographiclatitude                                           None
# subobserverplanetographiclatitude                                        None
# planetocentriclatitude             SURFACEGEOadrastea_planetocentriclatitude2
# subsolarplanetocentriclatitude                                           None
# subobserverplanetocentriclatitude                                        None
# IAUwestlongitude                         SURFACEGEOadrastea_IAUwestlongitude2
# subsolarIAUlongitude                                                     None
# subobserverIAUlongitude                                                  None
# observerlongitude                       SURFACEGEOadrastea_observerlongitude2
# rangetobody                                   SURFACEGEOadrastea_rangetobody2
# centerdistance                                                           None
# finestresolution                         SURFACEGEOadrastea_finestresolution2
# coarsestresolution                     SURFACEGEOadrastea_coarsestresolution2
# centerresolution                                                         None
# centerphaseangle                                                         None
# phase                                               SURFACEGEOadrastea_phase2
# incidence                                       SURFACEGEOadrastea_incidence2
# emission                                         SURFACEGEOadrastea_emission2
# solarhourangle                             SURFACEGEOadrastea_solarhourangle2
#
#                                                                          full_label1  \
# planetographiclatitude             Observed Planetographic Latitude (Min) [Adrastea]
# subsolarplanetographiclatitude          Sub-Solar Planetographic Latitude [Adrastea]
# subobserverplanetographiclatitude    Sub-Observer Planetographic Latitude [Adrastea]
# planetocentriclatitude             Observed Planetocentric Latitude (Min) [Adrastea]
# subsolarplanetocentriclatitude          Sub-Solar Planetocentric Latitude [Adrastea]
# subobserverplanetocentriclatitude    Sub-Observer Planetocentric Latitude [Adrastea]
# IAUwestlongitude                        Observed IAU West Longitude (Min) [Adrastea]
# subsolarIAUlongitude                         Sub-Solar IAU West Longitude [Adrastea]
# subobserverIAUlongitude                   Sub-Observer IAU West Longitude [Adrastea]
# observerlongitude                            Longitude WRT Observer (Min) [Adrastea]
# rangetobody                            Observed Distance to Surface (Min) [Adrastea]
# centerdistance                                       Body Center Distance [Adrastea]
# finestresolution                         Finest Observed Resolution (Min) [Adrastea]
# coarsestresolution                     Coarsest Observed Resolution (Min) [Adrastea]
# centerresolution                                   Body Center Resolution [Adrastea]
# centerphaseangle                               Phase Angle at Body Center [Adrastea]
# phase                                          Observed Phase Angle (Min) [Adrastea]
# incidence                                  Observed Incidence Angle (Min) [Adrastea]
# emission                                    Observed Emission Angle (Min) [Adrastea]
# solarhourangle                            Observed Local Hour Angle (Min) [Adrastea]
#
#                                                                          full_label2  \
# planetographiclatitude             Observed Planetographic Latitude (Max) [Adrastea]
# subsolarplanetographiclatitude                                                  None
# subobserverplanetographiclatitude                                               None
# planetocentriclatitude             Observed Planetocentric Latitude (Max) [Adrastea]
# subsolarplanetocentriclatitude                                                  None
# subobserverplanetocentriclatitude                                               None
# IAUwestlongitude                        Observed IAU West Longitude (Max) [Adrastea]
# subsolarIAUlongitude                                                            None
# subobserverIAUlongitude                                                         None
# observerlongitude                            Longitude WRT Observer (Max) [Adrastea]
# rangetobody                            Observed Distance to Surface (Max) [Adrastea]
# centerdistance                                                                  None
# finestresolution                         Finest Observed Resolution (Max) [Adrastea]
# coarsestresolution                     Coarsest Observed Resolution (Max) [Adrastea]
# centerresolution                                                                None
# centerphaseangle                                                                None
# phase                                          Observed Phase Angle (Max) [Adrastea]
# incidence                                  Observed Incidence Angle (Max) [Adrastea]
# emission                                    Observed Emission Angle (Max) [Adrastea]
# solarhourangle                            Observed Local Hour Angle (Max) [Adrastea]
#
#                                                                  full_search_label  \
# planetographiclatitude                 Observed Planetographic Latitude [Adrastea]
# subsolarplanetographiclatitude        Sub-Solar Planetographic Latitude [Adrastea]
# subobserverplanetographiclatitude  Sub-Observer Planetographic Latitude [Adrastea]
# planetocentriclatitude                 Observed Planetocentric Latitude [Adrastea]
# subsolarplanetocentriclatitude        Sub-Solar Planetocentric Latitude [Adrastea]
# subobserverplanetocentriclatitude  Sub-Observer Planetocentric Latitude [Adrastea]
# IAUwestlongitude                            Observed IAU West Longitude [Adrastea]
# subsolarIAUlongitude                       Sub-Solar IAU West Longitude [Adrastea]
# subobserverIAUlongitude                 Sub-Observer IAU West Longitude [Adrastea]
# observerlongitude                                Longitude WRT Observer [Adrastea]
# rangetobody                                Observed Distance to Surface [Adrastea]
# centerdistance                                     Body Center Distance [Adrastea]
# finestresolution                             Finest Observed Resolution [Adrastea]
# coarsestresolution                         Coarsest Observed Resolution [Adrastea]
# centerresolution                                 Body Center Resolution [Adrastea]
# centerphaseangle                             Phase Angle at Body Center [Adrastea]
# phase                                              Observed Phase Angle [Adrastea]
# incidence                                      Observed Incidence Angle [Adrastea]
# emission                                        Observed Emission Angle [Adrastea]
# solarhourangle                                Observed Local Hour Angle [Adrastea]
#
#                                                                    label1  \
# planetographiclatitude             Observed Planetographic Latitude (Min)
# subsolarplanetographiclatitude          Sub-Solar Planetographic Latitude
# subobserverplanetographiclatitude    Sub-Observer Planetographic Latitude
# planetocentriclatitude             Observed Planetocentric Latitude (Min)
# subsolarplanetocentriclatitude          Sub-Solar Planetocentric Latitude
# subobserverplanetocentriclatitude    Sub-Observer Planetocentric Latitude
# IAUwestlongitude                        Observed IAU West Longitude (Min)
# subsolarIAUlongitude                         Sub-Solar IAU West Longitude
# subobserverIAUlongitude                   Sub-Observer IAU West Longitude
# observerlongitude                            Longitude WRT Observer (Min)
# rangetobody                            Observed Distance to Surface (Min)
# centerdistance                                       Body Center Distance
# finestresolution                         Finest Observed Resolution (Min)
# coarsestresolution                     Coarsest Observed Resolution (Min)
# centerresolution                                   Body Center Resolution
# centerphaseangle                               Phase Angle at Body Center
# phase                                          Observed Phase Angle (Min)
# incidence                                  Observed Incidence Angle (Min)
# emission                                    Observed Emission Angle (Min)
# solarhourangle                            Observed Local Hour Angle (Min)
#
#                                                                    label2  \
# planetographiclatitude             Observed Planetographic Latitude (Max)
# subsolarplanetographiclatitude                                       None
# subobserverplanetographiclatitude                                    None
# planetocentriclatitude             Observed Planetocentric Latitude (Max)
# subsolarplanetocentriclatitude                                       None
# subobserverplanetocentriclatitude                                    None
# IAUwestlongitude                        Observed IAU West Longitude (Max)
# subsolarIAUlongitude                                                 None
# subobserverIAUlongitude                                              None
# observerlongitude                            Longitude WRT Observer (Max)
# rangetobody                            Observed Distance to Surface (Max)
# centerdistance                                                       None
# finestresolution                         Finest Observed Resolution (Max)
# coarsestresolution                     Coarsest Observed Resolution (Max)
# centerresolution                                                     None
# centerphaseangle                                                     None
# phase                                          Observed Phase Angle (Max)
# incidence                                  Observed Incidence Angle (Max)
# emission                                    Observed Emission Angle (Max)
# solarhourangle                            Observed Local Hour Angle (Max)
#
#                                                                      search_fieldid1  \
# planetographiclatitude                    SURFACEGEOadrastea_planetographiclatitude1
# subsolarplanetographiclatitude     SURFACEGEOadrastea_subsolarplanetographiclatit...
# subobserverplanetographiclatitude  SURFACEGEOadrastea_subobserverplanetographicla...
# planetocentriclatitude                    SURFACEGEOadrastea_planetocentriclatitude1
# subsolarplanetocentriclatitude     SURFACEGEOadrastea_subsolarplanetocentriclatit...
# subobserverplanetocentriclatitude  SURFACEGEOadrastea_subobserverplanetocentricla...
# IAUwestlongitude                                SURFACEGEOadrastea_IAUwestlongitude1
# subsolarIAUlongitude                        SURFACEGEOadrastea_subsolarIAUlongitude1
# subobserverIAUlongitude                  SURFACEGEOadrastea_subobserverIAUlongitude1
# observerlongitude                              SURFACEGEOadrastea_observerlongitude1
# rangetobody                                          SURFACEGEOadrastea_rangetobody1
# centerdistance                                    SURFACEGEOadrastea_centerdistance1
# finestresolution                                SURFACEGEOadrastea_finestresolution1
# coarsestresolution                            SURFACEGEOadrastea_coarsestresolution1
# centerresolution                                SURFACEGEOadrastea_centerresolution1
# centerphaseangle                                SURFACEGEOadrastea_centerphaseangle1
# phase                                                      SURFACEGEOadrastea_phase1
# incidence                                              SURFACEGEOadrastea_incidence1
# emission                                                SURFACEGEOadrastea_emission1
# solarhourangle                                    SURFACEGEOadrastea_solarhourangle1
#
#                                                                      search_fieldid2  \
# planetographiclatitude                    SURFACEGEOadrastea_planetographiclatitude2
# subsolarplanetographiclatitude     SURFACEGEOadrastea_subsolarplanetographiclatit...
# subobserverplanetographiclatitude  SURFACEGEOadrastea_subobserverplanetographicla...
# planetocentriclatitude                    SURFACEGEOadrastea_planetocentriclatitude2
# subsolarplanetocentriclatitude     SURFACEGEOadrastea_subsolarplanetocentriclatit...
# subobserverplanetocentriclatitude  SURFACEGEOadrastea_subobserverplanetocentricla...
# IAUwestlongitude                                SURFACEGEOadrastea_IAUwestlongitude2
# subsolarIAUlongitude                        SURFACEGEOadrastea_subsolarIAUlongitude2
# subobserverIAUlongitude                  SURFACEGEOadrastea_subobserverIAUlongitude2
# observerlongitude                              SURFACEGEOadrastea_observerlongitude2
# rangetobody                                          SURFACEGEOadrastea_rangetobody2
# centerdistance                                    SURFACEGEOadrastea_centerdistance2
# finestresolution                                SURFACEGEOadrastea_finestresolution2
# coarsestresolution                            SURFACEGEOadrastea_coarsestresolution2
# centerresolution                                SURFACEGEOadrastea_centerresolution2
# centerphaseangle                                SURFACEGEOadrastea_centerphaseangle2
# phase                                                      SURFACEGEOadrastea_phase2
# incidence                                              SURFACEGEOadrastea_incidence2
# emission                                                SURFACEGEOadrastea_emission2
# solarhourangle                                    SURFACEGEOadrastea_solarhourangle2
#
#                                                            search_label  \
# planetographiclatitude                 Observed Planetographic Latitude
# subsolarplanetographiclatitude        Sub-Solar Planetographic Latitude
# subobserverplanetographiclatitude  Sub-Observer Planetographic Latitude
# planetocentriclatitude                 Observed Planetocentric Latitude
# subsolarplanetocentriclatitude        Sub-Solar Planetocentric Latitude
# subobserverplanetocentriclatitude  Sub-Observer Planetocentric Latitude
# IAUwestlongitude                            Observed IAU West Longitude
# subsolarIAUlongitude                       Sub-Solar IAU West Longitude
# subobserverIAUlongitude                 Sub-Observer IAU West Longitude
# observerlongitude                                Longitude WRT Observer
# rangetobody                                Observed Distance to Surface
# centerdistance                                     Body Center Distance
# finestresolution                             Finest Observed Resolution
# coarsestresolution                         Coarsest Observed Resolution
# centerresolution                                 Body Center Resolution
# centerphaseangle                             Phase Angle at Body Center
# phase                                              Observed Phase Angle
# incidence                                      Observed Incidence Angle
# emission                                        Observed Emission Angle
# solarhourangle                                Observed Local Hour Angle
#
#                                    single_value             type
# planetographiclatitude                    False      range_float
# subsolarplanetographiclatitude             True      range_float
# subobserverplanetographiclatitude          True      range_float
# planetocentriclatitude                    False      range_float
# subsolarplanetocentriclatitude             True      range_float
# subobserverplanetocentriclatitude          True      range_float
# IAUwestlongitude                          False  range_longitude
# subsolarIAUlongitude                       True  range_longitude
# subobserverIAUlongitude                    True  range_longitude
# observerlongitude                         False  range_longitude
# rangetobody                               False      range_float
# centerdistance                             True      range_float
# finestresolution                          False      range_float
# coarsestresolution                        False      range_float
# centerresolution                           True      range_float
# centerphaseangle                           True      range_float
# phase                                     False      range_float
# incidence                                 False      range_float
# emission                                  False      range_float
# solarhourangle                            False  range_longitude

# %%
O.make_surfacegeo_field('S/2004 S 12', 'solarhourangle')
# Out:
# 'SURFACEGEOs2004s12_solarhourangle'

# %%
O.make_surfacegeo_field('s/2004 s 12', 'solarhourangle') # Case-insensitive!
# Out:
# 'SURFACEGEOs2004s12_solarhourangle'

# %%
O.make_surfacegeo_field('s2004s12', 'solarhourangle')
# Out:
# 'SURFACEGEOs2004s12_solarhourangle'

# %%
O.make_surfacegeo_field('S2004S12', 'solarhourangle') # Case-insensitive!
# Out:
# 'SURFACEGEOs2004s12_solarhourangle'

# %% [markdown]
# # **Queries**

# %%
mq1=MultQuery('target', 'Saturn Rings')

# %%
mq1
# Out:
# MultQuery('target','Saturn Rings')

# %%
print(mq1)
# Out:
# MultQuery target=Saturn Rings

# %%
mq2=MultQuery('planet',['Earth','Jupiter','Saturn'])

# %%
mq2
# Out:
# MultQuery('planet',['Earth', 'Jupiter', 'Saturn'])

# %%
print(mq2)
# Out:
# MultQuery planet=Earth,Jupiter,Saturn

# %%
sq1=StringQuery('volumeid', 'COISS_2001')

# %%
sq1
# Out:
# StringQuery('volumeid','COISS_2001','contains')

# %%
print(sq1)
# Out:
# StringQuery volumeid=COISS_2001 (contains)

# %%
sq2=StringQuery('volumeid', 'COISS_2002', 'matches')

# %%
sq2
# Out:
# StringQuery('volumeid','COISS_2002','matches')

# %%
print(sq2)
# Out:
# StringQuery volumeid=COISS_2002 (matches)

# %%
rq1=RangeQuery('rightasc', minimum=10)

# %%
rq1
# Out:
# RangeQuery('rightasc',minimum=10.0)

# %%
print(rq1)
# Out:
# RangeQuery rightasc min=10.0

# %%
rq2=RangeQuery('rightasc', maximum=30)

# %%
rq2
# Out:
# RangeQuery('rightasc',maximum=30.0)

# %%
print(rq2)
# Out:
# RangeQuery rightasc max=30.0

# %%
rq3=RangeQuery('rightasc', minimum=30, maximum=35, qtype='any')

# %%
rq3
# Out:
# RangeQuery('rightasc',minimum=30.0,maximum=35.0,qtype='any')

# %%
print(rq3)
# Out:
# RangeQuery rightasc min=30.0 max=35.0 (qtype any)

# %%
rq4=RangeQuery('rightasc', minimum=70, maximum=90, qtype='only', unit='degrees')

# %%
rq4
# Out:
# RangeQuery('rightasc',minimum=70.0,maximum=90.0,qtype='only',unit='degrees')

# %%
print(rq4)
# Out:
# RangeQuery rightasc min=70.0 max=90.0 (qtype only) [degrees]

# %%
q1=Query(mq1,mq2,OR(sq1,sq2),OR(rq3,rq4))

# %%
q1
# Out:
# Query(MultQuery('target','Saturn Rings'),MultQuery('planet',['Earth', 'Jupiter', 'Saturn']),OR(StringQuery('volumeid','COISS_2001','contains'),StringQuery('volumeid','COISS_2002','matches')),OR(RangeQuery('rightasc',minimum=30.0,maximum=35.0,qtype='any'),RangeQuery('rightasc',minimum=70.0,maximum=90.0,qtype='only',unit='degrees')))

# %%
print(q1)
# Out:
# OPUS Query with search terms:
#   MultQuery target=Saturn Rings
#   MultQuery planet=Earth,Jupiter,Saturn
#   OR:
#     StringQuery volumeid=COISS_2001 (contains)
#     StringQuery volumeid=COISS_2002 (matches)
#   OR:
#     RangeQuery rightasc min=30.0 max=35.0 (qtype any)
#     RangeQuery rightasc min=70.0 max=90.0 (qtype only) [degrees]

# %%
q1.get_api_params(O)
# Out:
# {'planet': 'Earth,Jupiter,Saturn',
#  'qtype-rightasc_1': 'any',
#  'qtype-rightasc_2': 'only',
#  'qtype-volumeid_1': 'contains',
#  'qtype-volumeid_2': 'matches',
#  'rightasc1_1': 30.0,
#  'rightasc1_2': 70.0,
#  'rightasc2_1': 35.0,
#  'rightasc2_2': 90.0,
#  'target': 'Saturn Rings',
#  'unit-rightasc_2': 'degrees',
#  'volumeid_1': 'COISS_2001',
#  'volumeid_2': 'COISS_2002'}

# %% [markdown]
# # Meta API Calls

# %%
O.get_count(q1)
# Out:
# 24

# %%
O.get_mults('COISScamera', q1)
# Out:
# {'Wide Angle': 24}

# %% [markdown]
# ## There is actually a bug in the real OPUS API that I found here! It is not returning "mult" fields that have zero search results. I'll fix that shortly.

# %%
O.get_mults('COISScamera')
# Out:
# {'Narrow Angle': 318454, 'Wide Angle': 124723}

# %%
O.get_range_endpoints('greaterpixelsize')
# Out:
# ('1', '10037', 220232, None)

# %%
O.get_range_endpoints('greaterpixelsize', q1)
# Out:
# ('1024', '1024', 0, None)
